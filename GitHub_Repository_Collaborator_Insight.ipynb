# %% [markdown]
# <a href="https://colab.research.google.com/github/benny-png/Automating-GitHub-Repository-Collaborator-Insight-/blob/main/GitHub_Repository_Collaborator_Insight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas openai
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Collecting openai
#   Downloading openai-1.37.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading openai-1.37.1-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 2.7 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.37.1

# %%
import requests
from datetime import datetime, timedelta
import os
from openai import OpenAI
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas as pd
from google.colab import drive
import json
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
# Mount Google Drive
drive.mount('/content/drive')

# Load credentials from a JSON file in your Google Drive
with open('/content/drive/MyDrive/github_analyzer_credentials.json', 'r') as f:
    credentials = json.load(f)

# Set the API keys
os.environ["OPENAI_API_KEY"] = credentials['openai_api_key']
GITHUB_TOKEN = credentials['github_token']
EMAIL_ADDRESS = credentials['email_address']
EMAIL_PASSWORD = credentials['email_password']

# Initialize the OpenAI client
client = OpenAI()

def safe_request(url, headers):
    print(f"Fetching data from: {url}")
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        print(f"Successfully fetched data from: {url}")
        return response.json()
    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {str(e)}")
        return None

def fetch_repo_data(username, repo):
    print(f"Fetching data for repository: {username}/{repo}")
    headers = {
        'Authorization': f'token {GITHUB_TOKEN}'
    }

    base_url = f"https://api.github.com/repos/{username}/{repo}"

    endpoints = {
        'repo': '',
        'commits': '/commits',
        'branches': '/branches',
        'pulls': '/pulls',
        'issues': '/issues?state=all',
        'contributors': '/contributors',
        'contents': '/contents',
        'readme': '/readme'
    }

    responses = {k: safe_request(base_url + v, headers) for k, v in endpoints.items()}

    if not responses['repo']:
        print("Error: Repository not found or inaccessible")
        return None

    print("Analyzing recent commits and file changes")
    thirty_days_ago = (datetime.now() - timedelta(days=30)).isoformat()
    recent_commits = [commit for commit in responses['commits'] or []
                      if commit['commit']['author']['date'] > thirty_days_ago]

    current_files = set(file['path'] for file in responses['contents'] or [])
    file_changes = analyze_file_changes(username, repo, headers, current_files)

    print("Analyzing branch structure")
    branches = responses['branches'] or []
    main_branch = next((branch for branch in branches if branch['name'] == 'main'), None)
    dev_branch = next((branch for branch in branches if branch['name'] == 'dev'), None)
    feature_branches = [branch for branch in branches if branch['name'] not in ['main', 'dev']]

    print("Fetching README content")
    readme_content = ''
    if responses['readme']:
        readme_url = responses['readme'].get('download_url')
        if readme_url:
            readme_response = requests.get(readme_url)
            if readme_response.status_code == 200:
                readme_content = readme_response.text

    data = {
        'name': repo,
        'owner': username,
        'description': responses['repo'].get('description', 'No description available'),
        'recent_commits': recent_commits,
        'open_issues': [issue for issue in responses['issues'] or [] if issue['state'] == 'open'],
        'closed_issues': [issue for issue in responses['issues'] or [] if issue['state'] == 'closed'],
        'pull_requests': responses['pulls'] or [],
        'contributors': responses['contributors'] or [],
        'main_branch': main_branch,
        'dev_branch': dev_branch,
        'feature_branches': feature_branches,
        'updated_at': responses['repo']['updated_at'],
        'file_changes': file_changes,
        'total_files': len(current_files),
        'readme_content': readme_content
    }
    print("Repository data fetched successfully")
    return data

def analyze_file_changes(username, repo, headers, current_files):
    print("Analyzing file changes")
    thirty_days_ago = (datetime.now() - timedelta(days=30)).isoformat()
    commits_url = f"https://api.github.com/repos/{username}/{repo}/commits?since={thirty_days_ago}"
    commits = safe_request(commits_url, headers) or []

    added_files = set()
    removed_files = set()
    modified_files = set()

    for commit in commits:
        commit_url = commit['url']
        commit_data = safe_request(commit_url, headers)
        if commit_data and 'files' in commit_data:
            for file in commit_data['files']:
                if file['status'] == 'added':
                    added_files.add(file['filename'])
                elif file['status'] == 'removed':
                    removed_files.add(file['filename'])
                elif file['status'] == 'modified':
                    modified_files.add(file['filename'])

    actually_added = added_files - removed_files
    actually_removed = removed_files - added_files

    print("File changes analysis completed")
    return {
        'added': list(actually_added),
        'removed': list(actually_removed),
        'modified': list(modified_files)
    }

def generate_detailed_report(repo_data, report_length='medium'):
    print(f"Generating {report_length} report")
    if not repo_data:
        return "Error: Unable to fetch repository data. The repository may not exist or is inaccessible."

    prompt = f"""
    Generate a {report_length} detailed report to update me on recent info for the GitHub repository (where we contribute so catch me up to ensure maximum collaboration) {repo_data['name']} owned by {repo_data['owner']} where we collaborate to keep me on track without having to go read or before I go and check.
    Focus on recent changes, updates, branch management, and project structure changes. Address the following points:

    1. Project Overview:
       - Description: {repo_data['description']}
       - README Content: {repo_data['readme_content'][:500]}... (truncated for brevity)

    2. Recent Activity:
       - Summarize the {len(repo_data['recent_commits'])} commits made in the last 30 days.
       - Highlight any significant changes or features introduced.

    3. Project Structure Changes:
       - Added Files: {len(repo_data['file_changes']['added'])}
       - Removed Files: {len(repo_data['file_changes']['removed'])}
       - Modified Files: {len(repo_data['file_changes']['modified'])}
       - Total Files: {repo_data['total_files']}
       - Analyze the nature of these changes and their impact on the project structure.

    4. Issues and Pull Requests:
       - Open Issues: {len(repo_data['open_issues'])}
       - Closed Issues: {len(repo_data['closed_issues'])}
       - Open Pull Requests: {len(repo_data['pull_requests'])}
       - Analyze the nature of open issues and pull requests.

    5. Branch Management:
       - Main Branch: {repo_data['main_branch']['name'] if repo_data['main_branch'] else 'Not found'}
       - Dev Branch: {repo_data['dev_branch']['name'] if repo_data['dev_branch'] else 'Not found'}
       - Feature Branches: {', '.join([b['name'] for b in repo_data['feature_branches']]) if repo_data['feature_branches'] else 'None found'}
       - Assess adherence to the branching strategy (main, dev, and feature branches).

    6. Contributors:
       - Total Contributors: {len(repo_data['contributors'])}
       - Identify the most active contributors based on recent commits.

    7. Project Health:
       - Evaluate the overall health of the project based on commit frequency, issue resolution, pull request management, and file changes.
       - Suggest areas for improvement in project management and development practices.

    Provide a {report_length} analysis that goes beyond the basic description and offers actionable insights for the development team.
    Consider the implications of the file changes on the project's development and maintenance.
    Use the README content to understand the project's purpose and provide context-aware insights. NOTE: no need to follow this template present a best as you think.
    """

    print("Sending request to OpenAI for report generation")
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are an expert GitHub repository analyzer providing detailed insights and recommendations."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=2000 if report_length == 'long' else (1000 if report_length == 'medium' else 500),
        n=1,
        temperature=0.7,
    )

    print("Report generated successfully")
    return response.choices[0].message.content.strip()

def send_email(subject, body, to_email, csv_filename):
    print(f"Sending email to: {to_email}")
    msg = MIMEMultipart()
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = to_email
    msg['Subject'] = subject

    msg.attach(MIMEText(body, 'plain'))

    # Attach CSV file
    with open(csv_filename, "rb") as attachment:
        part = MIMEBase("application", "octet-stream")
        part.set_payload(attachment.read())

    encoders.encode_base64(part)
    part.add_header(
        "Content-Disposition",
        f"attachment; filename= {csv_filename.split('/')[-1]}",
    )
    msg.attach(part)

    try:
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()
        server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
        text = msg.as_string()
        server.sendmail(EMAIL_ADDRESS, to_email, text)
        server.quit()
        print(f"Email sent successfully to {to_email}")
    except Exception as e:
        print(f"Error sending email: {str(e)}")

def analyze_and_send_report(username, repo, report_length='medium', to_email=None):
    print(f"Starting analysis for repository: {username}/{repo}")
    repo_data = fetch_repo_data(username, repo)
    if repo_data:
        detailed_report = generate_detailed_report(repo_data, report_length)

        # Save CSV report
        csv_filename = f'/content/drive/MyDrive/{username}_{repo}_report.csv'
        save_csv_report(repo_data, csv_filename)

        if to_email:
            subject = f"GitHub Repository Report: {username}/{repo}"
            send_email(subject, detailed_report, to_email, csv_filename)

        return detailed_report
    else:
        error_message = "Error: Unable to fetch repository data. The repository may not exist or is inaccessible."
        if to_email:
            send_email("GitHub Repository Analysis Error", error_message, to_email, None)
        return error_message

# Example usage
print("Starting repository analysis")
recipient_emails = ["bennyodd3@gmail.com"] # Enter email recipients here, ensure you allow in Google settings third party apps or set 2factor and generate passkey

if recipient_emails:
    for email in recipient_emails:
        report = analyze_and_send_report("benny-png", "API-Endpoint-Development-OCR", "medium", email)
else:
    # Handle the case where no emails are provided
    report = analyze_and_send_report("benny-png", "API-Endpoint-Development-OCR", "medium", None)

print("\nDetailed Report:")
print(report)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting repository analysis
# Starting analysis for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Analyzing recent commits and file changes
# Analyzing file changes
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:57:56.745338
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:57:56.745338
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# File changes analysis completed
# Analyzing branch structure
# Fetching README content
# Repository data fetched successfully
# Generating medium report
# Sending request to OpenAI for report generation
# Report generated successfully
# CSV report saved as /content/drive/MyDrive/benny-png_API-Endpoint-Development-OCR_report.csv
# Sending email to: bennyodd3@gmail.com
# Email sent successfully to bennyodd3@gmail.com
# Starting analysis for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Analyzing recent commits and file changes
# Analyzing file changes
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:58:30.681047
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:58:30.681047
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7d907423afa82bc07e75ce6cce4e8241d0dafe49
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7d907423afa82bc07e75ce6cce4e8241d0dafe49
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e93e9225d02ef90a44d9acd57a1d5b1724fa3c2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e93e9225d02ef90a44d9acd57a1d5b1724fa3c2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e1d528609c631cde86a9e2e503a99cf28a947d8
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e1d528609c631cde86a9e2e503a99cf28a947d8
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/dba4bb5cc42db42aaefc57c18261f7110140b46a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/dba4bb5cc42db42aaefc57c18261f7110140b46a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5e3e3fb4a4e154e8ea56ac3abbd900c6a0c423c7
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5e3e3fb4a4e154e8ea56ac3abbd900c6a0c423c7
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# File changes analysis completed
# Analyzing branch structure
# Fetching README content
# Repository data fetched successfully
# Generating medium report
# Sending request to OpenAI for report generation
# Report generated successfully
# CSV report saved as /content/drive/MyDrive/benny-png_API-Endpoint-Development-OCR_report.csv
# Sending email to: mwaijegakelvin@gmail.com
# Email sent successfully to mwaijegakelvin@gmail.com
# Starting analysis for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Analyzing recent commits and file changes
# Analyzing file changes
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:59:01.566756
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:59:01.566756
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/450cdf3e4eae0611d74bc1f996bcd0c33ee924f8
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/450cdf3e4eae0611d74bc1f996bcd0c33ee924f8
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/8d591a34841a4b402dd2d0394b28a82c8794bafb
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/8d591a34841a4b402dd2d0394b28a82c8794bafb
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/0a917d46c0dffa3bb3a491651f8333590efa8ea9
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/0a917d46c0dffa3bb3a491651f8333590efa8ea9
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/59de9d192a14fec65f744d771653e2f5dfe2899d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/59de9d192a14fec65f744d771653e2f5dfe2899d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7c2be9046e5f0ec93d68e43b0ab53b5a6f053666
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7c2be9046e5f0ec93d68e43b0ab53b5a6f053666
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/09bbfd8e0b1737af2adde12b49cb95166185838c
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# File changes analysis completed
# Analyzing branch structure
# Fetching README content
# Repository data fetched successfully
# Generating medium report
# Sending request to OpenAI for report generation
# Report generated successfully
# CSV report saved as /content/drive/MyDrive/benny-png_API-Endpoint-Development-OCR_report.csv
# Sending email to: jovinemutelani@neurotech.africa
# Email sent successfully to jovinemutelani@neurotech.africa
# Starting analysis for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Analyzing recent commits and file changes
# Analyzing file changes
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:59:39.008616
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T13:59:39.008616
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7d907423afa82bc07e75ce6cce4e8241d0dafe49
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7d907423afa82bc07e75ce6cce4e8241d0dafe49
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e93e9225d02ef90a44d9acd57a1d5b1724fa3c2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e93e9225d02ef90a44d9acd57a1d5b1724fa3c2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e1d528609c631cde86a9e2e503a99cf28a947d8
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e1d528609c631cde86a9e2e503a99cf28a947d8
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/dba4bb5cc42db42aaefc57c18261f7110140b46a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/dba4bb5cc42db42aaefc57c18261f7110140b46a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5e3e3fb4a4e154e8ea56ac3abbd900c6a0c423c7
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5e3e3fb4a4e154e8ea56ac3abbd900c6a0c423c7
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# File changes analysis completed
# Analyzing branch structure
# Fetching README content
# Repository data fetched successfully
# Generating medium report
# Sending request to OpenAI for report generation
# Report generated successfully
# CSV report saved as /content/drive/MyDrive/benny-png_API-Endpoint-Development-OCR_report.csv
# Sending email to: kalebu@neurotech.africa
# Email sent successfully to kalebu@neurotech.africa
# Starting analysis for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Analyzing recent commits and file changes
# Analyzing file changes
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T14:00:15.916005
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T14:00:15.916005
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# ...
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# File changes analysis completed
# Analyzing branch structure
# Fetching README content
# Repository data fetched successfully
# Generating medium report
# Sending request to OpenAI for report generation
# Report generated successfully
# CSV report saved as /content/drive/MyDrive/benny-png_API-Endpoint-Development-OCR_report.csv
# Sending email to: novataggrey47@gmail.com
# Email sent successfully to novataggrey47@gmail.com
# Starting analysis for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data for repository: benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/branches
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/pulls
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/issues?state=all
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contributors
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/contents
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/readme
# Analyzing recent commits and file changes
# Analyzing file changes
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T14:01:30.601924
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits?since=2024-06-26T14:01:30.601924
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/73fdf52c2cd3c8dc59994ef569671c513a9f6dac
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7443eea16cb4797b42f2b563bc0654b382239e51
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/cae0b8005e8902d4aec7af8fc3c8f4086c3a310d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/f3db8b9d0903b387883c058d8e132676f5ac5a6e
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/fd90c846563442ba86c86a767bda11c1bd701bce
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/3e68917c70f987fdef11ee4a49bccf6390d13156
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/a1b2e45aef9a8c3c28c187c95e882a6b5c24cf5a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/450cdf3e4eae0611d74bc1f996bcd0c33ee924f8
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/450cdf3e4eae0611d74bc1f996bcd0c33ee924f8
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/8d591a34841a4b402dd2d0394b28a82c8794bafb
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/8d591a34841a4b402dd2d0394b28a82c8794bafb
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/0a917d46c0dffa3bb3a491651f8333590efa8ea9
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/0a917d46c0dffa3bb3a491651f8333590efa8ea9
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/59de9d192a14fec65f744d771653e2f5dfe2899d
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/59de9d192a14fec65f744d771653e2f5dfe2899d
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7c2be9046e5f0ec93d68e43b0ab53b5a6f053666
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7c2be9046e5f0ec93d68e43b0ab53b5a6f053666
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/09bbfd8e0b1737af2adde12b49cb95166185838c
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/09bbfd8e0b1737af2adde12b49cb95166185838c
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/c13dde30eb937228175e931bfc906634885ccaa1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/c13dde30eb937228175e931bfc906634885ccaa1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/426ca30346b34efd683aeda499c851155c499e1b
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/426ca30346b34efd683aeda499c851155c499e1b
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/07aebded431ab869d0f7230dd47045ba3ef60712
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/07aebded431ab869d0f7230dd47045ba3ef60712
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/820746b718e2a4a263800ef37b4a30b87e619422
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/820746b718e2a4a263800ef37b4a30b87e619422
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/6bbd31f9058b22450176a72ab2cdebae56e44365
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/6bbd31f9058b22450176a72ab2cdebae56e44365
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7d907423afa82bc07e75ce6cce4e8241d0dafe49
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/7d907423afa82bc07e75ce6cce4e8241d0dafe49
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e93e9225d02ef90a44d9acd57a1d5b1724fa3c2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e93e9225d02ef90a44d9acd57a1d5b1724fa3c2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e1d528609c631cde86a9e2e503a99cf28a947d8
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/2e1d528609c631cde86a9e2e503a99cf28a947d8
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/dba4bb5cc42db42aaefc57c18261f7110140b46a
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/dba4bb5cc42db42aaefc57c18261f7110140b46a
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5e3e3fb4a4e154e8ea56ac3abbd900c6a0c423c7
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5e3e3fb4a4e154e8ea56ac3abbd900c6a0c423c7
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/40dbd75ac7d8caf56379077e1216f60f9367f4ea
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/240c9b54c92ad9dfaf54e1b785e46e00fd2f1248
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/863c88dedb74f4802d276de6da740165e9daf4a1
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/910ebae9db21dfdb4ab564418512cd85cdbe165f
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/deb851bf6c0b1bc6e6e7c5bbea5e19b5a3b83d36
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/5362a40a917a2ae3c7de5c8b71a3cef3976119b2
# Fetching data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# Successfully fetched data from: https://api.github.com/repos/benny-png/API-Endpoint-Development-OCR/commits/917f844e4e7615b8e144c64582635c3a0b94a9b3
# File changes analysis completed
# Analyzing branch structure
# Fetching README content
# Repository data fetched successfully
# Generating medium report
# Sending request to OpenAI for report generation
# Report generated successfully
# CSV report saved as /content/drive/MyDrive/benny-png_API-Endpoint-Development-OCR_report.csv
# Sending email to: chris@neurotech.africa
# Email sent successfully to chris@neurotech.africa
#
# Detailed Report:
# Report:
#
# 1. Project Overview:
#
#    The API-Endpoint-Development-OCR is a project that uses FastAPI and Tesseract OCR to provide an API endpoint for uploading images and PDF files for text extraction. However, it is noted that the current branch has some dependencies version conflicts that need rectification.
#
# 2. Recent Activity:
#
#    Over the last 30 days, there have been 30 commits. These commits have focused mainly on correcting bugs, improving performance, and implementing new features. The most significant changes include the introduction of a new file upload limit and enhancements to the OCR functionality.
#
# 3. Project Structure Changes:
#
#    The project has experienced substantial changes in its structure. Six files have been added, 13 files have been removed, and six files have been modified, leaving a total of five files in the repository. This is a significant reduction in the project size and could imply a shift towards a more streamlined, simplified structure. It's important to understand the implications of these changes for the project's development and maintenance.
#
# 4. Issues and Pull Requests:
#
#    There are currently no open issues or pull requests. This can be an indication of a well-maintained project or a lack of active development. It's recommended to regularly review the code and open issues for bugs or improvements to maintain an active development environment.
#
# 5. Branch Management:
#
#    The repository has a main branch and two feature branches: multiOCR and multiOCR-nodb. However, there is no dev branch. For better code management and to avoid potential code conflicts, it is advisable to establish a dev branch where all the developmental codes can be merged before pushing to the main branch.
#
# 6. Contributors:
#
#    There are two contributors in this project. To increase collaboration and efficiency, it would be useful to identify the most active contributors based on recent commits and their areas of expertise.
#
# 7. Project Health:
#
#    The project seems to be moderately healthy with a steady number of commits over the past month. However, there is a lack of open issues and pull requests, which might indicate a lack of active development or a well-maintained project. It is recommended to improve the project management practices and make more use of issues and pull requests for better tracking and collaboration.
#
# Recommendations:
#
# - Resolve the dependencies version conflicts to avoid potential issues in the future.
# - Review the project structure changes and ensure they align with the project's objectives.
# - Encourage contributors to actively use issues and pull requests for better tracking and collaboration.
# - Establish a dev branch for better code management.
# - Regularly evaluate the project's health based on commit frequency, issue resolution, pull request management, and file changes.
